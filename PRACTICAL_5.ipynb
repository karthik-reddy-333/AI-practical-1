# %% [markdown]
# <a href="https://colab.research.google.com/github/karthik-reddy-333/AI-practical-1/blob/main/PRACTICAL_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PRACTICAL-5

# %%
def laptop_expert(turns_on, internet_works, is_slow):
    if turns_on == 'no':
        return "Check power source and battery."
    elif internet_works == 'no':
        return "Check Wi-Fi connection, router, or network settings."
    elif is_slow == 'yes':
        return "Consider cleaning up disk space, closing unnecessary applications, or upgrading RAM."
    else:
        return "Your laptop seems to be working fine!"

turns_on = input("Does the laptop turn on? yes/no: ").lower()
internet_works = input("Does the internet work? yes/no: ").lower()
is_slow = input("Is the laptop slow? yes/no: ").lower()
advice = laptop_expert(turns_on, internet_works, is_slow)
print("\nExpert System Advice:")
print(advice)
# Out:
# Does the laptop turn on? yes/no: yes
# Does the internet work? yes/no: no
# Is the laptop slow? yes/no: no
#
# Expert System Advice:
# Check Wi-Fi connection, router, or network settings.
