# %% [markdown]
# <a href="https://colab.research.google.com/github/karthik-reddy-333/AI-practical-1/blob/main/AI_lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PRACTICAL-1

# %%
print("Hello! I am Python.")
print("Today we will build a cleaning robot together.")
print(2 + 3, "is the answer to 2 + 3")


room = ["D", "C", "D", "D", "C"]


def show_room(room):
    picture = ""
    for spot in room:
        if spot == "D":
            picture += "💩 "
        else:
            picture += "✨ "
    print(picture)

print("Our room right now:")
show_room(room)


def clean_spot(spot):
    if spot == "D":
        return "C"
    else:
        return "C"


result = clean_spot("D")
print("The robot looked at a dirty spot 💩 and made it:", result,
      "(C means clean ✨)")

print("BEFORE - the dirty room:")
show_room(room)


for i in range(len(room)):
    room[i] = clean_spot(room[i])
    print("After cleaning spot number", i + 1, ":")
    show_room(room)

print()
print("AFTER - all done ✨🤖✨")


room2 = ["D", "C", "D", "D", "C"]

cleaned = 0

for i in range(len(room2)):
    if room2[i] == "D":
        cleaned = cleaned + 1
    room2[i] = clean_spot(room2[i])

print("The robot cleaned", cleaned, "dirty spots.")
print("The room is now:")
show_room(room2)
# Out:
# Hello! I am Python.
# Today we will build a cleaning robot together.
# 5 is the answer to 2 + 3
# Our room right now:
# 💩 ✨ 💩 💩 ✨
# The robot looked at a dirty spot 💩 and made it: C (C means clean ✨)
# BEFORE - the dirty room:
# 💩 ✨ 💩 💩 ✨
# After cleaning spot number 1 :
# ✨ ✨ 💩 💩 ✨
# After cleaning spot number 2 :
# ✨ ✨ 💩 💩 ✨
# After cleaning spot number 3 :
# ✨ ✨ ✨ 💩 ✨
# After cleaning spot number 4 :
# ✨ ✨ ✨ ✨ ✨
# After cleaning spot number 5 :
# ✨ ✨ ✨ ✨ ✨
#
# AFTER - all done ✨🤖✨
# The robot cleaned 3 dirty spots.
# The room is now:
# ✨ ✨ ✨ ✨ ✨

# %% [markdown]
# PRACTICAL-2

# %%
def chatbot():
    print("hello i'm karthik")


    while True:
        user = input("You: ")
        if user == '1':
            print("I am here to help!")
        elif user == '2':
            print("chess champion Magnus carlsen")
        elif user == '3':
            print("see u later")
            break
        else:
            print("Please choose 1, 2, or 3.")

chatbot()
# Out:
# hello i'm karthik
# You: 1
# I am here to help!
# You: 2
# chess champion Magnus carlsen
# You: 3
# see u later

# %%
map_room = {
"A" : ["B","C"],
"B" : ["D"],
"C" : ["D"],
"D" : ["G"],
"G" : [],
}
print("Our map:")
print("             A (start)"               )
print("            /  \\" )
print("            B   C    ")
print("            \\   /      ")
print("               D")
print("               -")
print("                G (True sure )")

print("Doors from each room;", map_room)
# Out:
# Our map:
#              A (start)
#             /  \
#             B   C
#             \   /
#                D
#                -
#                 G (True sure )
# Doors from each room; {'A': ['B', 'C'], 'B': ['D'], 'C': ['D'], 'D': ['G'], 'G': []}

# %%
def bfs (start,goal):
    to_do = [start]
    visited = []
    order = []

    while to_do:
        room = to_do.pop(0)
        if room in visited:
            continue
        visited.append(room)
        order.append(room)
        if room == goal:
            return order
        for neighbour in map_room[room]:
            to_do.append(neighbour)
    return order
order = bfs("A","G")
print("BFS order:", order)
# Out:
# BFS order: ['A', 'B', 'C', 'D', 'G']

# %%
def dfs (start,goal):
    to_do = [start]
    visited = []
    order = []

    while to_do:
        room = to_do.pop()
        if room in visited:
            continue
        visited.append(room)
        order.append(room)
        if room == goal:
            return order
        for neighbour in map_room[room]:
            to_do.append(neighbour)
    return order
order = dfs("A","G")
print("dfs order:", order)
# Out:
# dfs order: ['A', 'C', 'D', 'G']

# %%
door_cost={("A","B"):1,
           ("B","D"):1,
           ("D","G"):1,
           ("A","C"):5,
           ("C","D"):1
          }
def path_cost(path):
    total=0
    for i in range(len(path) - 1):
        door =(path[i],path[i+1])
        total+= door_cost[door]
    return total
path1=["A","B","D","G"]
path2=["A","C","D","G"]
path1_cost=path_cost(path1)
path2_cost=path_cost(path2)
print("cost of path1: " ,path1_cost)
print("cost of path2: " ,path2_cost)
if path1_cost <= path2_cost :
    print("best path: ", path1 , "best cost: ",path1_cost)
else:
     print("best path: ", path2 , "best cost: ",path2_cost)
# Out:
# cost of path1:  3
# cost of path2:  7
# best path:  ['A', 'B', 'D', 'G'] best cost:  3

# %%
if cost1 < cost2:
    best_path = path1
    best_cost = cost1
else:
    best_path = path2
    best_cost = cost2

print("Path 1 cost:", cost1)
print("Path 2 cost:", cost2)
print("The cheapest path is", best_path, "with cost", best_cost, )

bfs_order = dfs("A", "G")
dfs_order = dfs("A", "G")
# Out:
# Path 1 cost: 3
# Path 2 cost: 7
# The cheapest path is ['A', 'B', 'D', 'G'] with cost 3

# %% [markdown]
# PRACTICAL-3
